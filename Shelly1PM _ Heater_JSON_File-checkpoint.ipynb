# %%
from pymongo import MongoClient
import datetime
import pyspark
from pyspark.sql import SparkSession
import json
import pandas as pd
import regex as re
from operator import itemgetter

# %% [markdown]
# #### extract json data from MongoDB Heater_Shelly1PM _ JSON_File

# %% [raw]
# #client= MongoClient("mongodb+srv://cecoDbUser:cecoUser2021@dashboard.agmyi.mongodb.net/DashBoard?retryWrites=true&w=majority")
#
# client.close()

# %% [raw]
# db = client.get_database('DashBoard')

# %% [raw]
# records = db.Heater_Shelly1PM

# %% [raw]
# records.count_documents({})

# %% [raw]
# list(records.find())

# %% [raw]
# list1=list(records.find({'roomId':'2'}))
# #list(records.find({'roomId':'2'}))
# #list(records.find({'roomId':'3'}))

# %% [raw]
# print(list1)

# %% [markdown]
# #### Save data in JSON file

# %% [raw]
# import sys
#
# orig_stdout = sys.stdout
# f = open('heater_room_2.json', 'w')
# sys.stdout = f
#
# for x in list1:
#     print(x)
#
# sys.stdout = orig_stdout
# f.close()

# %% [markdown]
# ##### read json file

# %%
with open('heater_room_2.json', 'r') as json_file:
    data = json_file.read()

print(data)
type(data)
# Out:
# {'_id': ObjectId('6113b015d9440b4a6c62cbe4'), 'wifi_sta': {'connected': True, 'ssid': 'Cecolab_WiFi', 'ip': '192.168.1.53', 'rssi': -64}, 'cloud': {'enabled': False, 'connected': False}, 'mqtt': {'connected': False}, 'time': '12:10', 'serial': 1, 'has_update': True, 'mac': '40F5200097E9', 'relays': [{'ison': True, 'has_timer': False, 'overpower': False}], 'meters': [{'power': 0.46, 'is_valid': True, 'timestamp': 1628683813, 'counters': [0.431, 0.433, 0.429], 'total': 258969}], 'inputs': [{'input': 0}], 'ext_temperature': {}, 'temperature': 49.61, 'overtemperature': False, 'tmp': {'tC': 49.61, 'tF': 121.3, 'is_valid': 'true'}, 'update': {'status': 'pending', 'has_update': True, 'new_version': '20210727-202339/v1.11.2-g25b6953', 'old_version': '20191219-114622/1047-long-id-for-shelly-devices@d05667c7'}, 'ram_total': 50680, 'ram_free': 39832, 'fs_size': 233681, 'fs_free': 172437, 'uptime': 431844, 'isError': False, 'deviceId': 'P1C2', 'roomId': '2', 'consumption_kwh': 7.666666666666667e
# ...

# %%
with open('test.json', 'r') as test_file:
    test_data = test_file.read()

# %%
obj = json.dumps(test_data)

# %%
json_test_data = json.loads(obj)

# %%
print(json_test_data)
# Out:
# {'_id': 'ObjectId'('6113b015d9440b4a6c62cbe4'), 'wifi_sta': {'connected': True, 'ssid': 'Cecolab_WiFi', 'ip': '192.168.1.53', 'rssi': -64}, 'cloud': {'enabled': False, 'connected': False}, 'mqtt': {'connected': False}, 'time': '12:10', 'serial': 1, 'has_update': True, 'mac': '40F5200097E9', 'relays': [{'ison': True, 'has_timer': False, 'overpower': False}], 'meters': [{'power': 0.46, 'is_valid': True, 'timestamp': 1628683813, 'counters': [0.431, 0.433, 0.429], 'total': 258969}], 'inputs': [{'input': 0}], 'ext_temperature': {}, 'temperature': 49.61, 'overtemperature': False, 'tmp': {'tC': 49.61, 'tF': 121.3, 'is_valid': 'true'}, 'update': {'status': 'pending', 'has_update': True, 'new_version': '20210727-202339/v1.11.2-g25b6953', 'old_version': '20191219-114622/1047-long-id-for-shelly-devices@d05667c7'}, 'ram_total': 50680, 'ram_free': 39832, 'fs_size': 233681, 'fs_free': 172437, 'uptime': 431844, 'isError': False, 'deviceId': 'P1C2', 'roomId': '2', 'consumption_kwh': 7.66666666666666
# ...

# %%
lineByLine = []
with open("test.json") as file:
    db = file.read()
    lineByLine.append(db)

print(lineByLine)
type(lineByLine)
# Out:
# ["{'_id': 'ObjectId'('6113b015d9440b4a6c62cbe4'), 'wifi_sta': {'connected': True, 'ssid': 'Cecolab_WiFi', 'ip': '192.168.1.53', 'rssi': -64}, 'cloud': {'enabled': False, 'connected': False}, 'mqtt': {'connected': False}, 'time': '12:10', 'serial': 1, 'has_update': True, 'mac': '40F5200097E9', 'relays': [{'ison': True, 'has_timer': False, 'overpower': False}], 'meters': [{'power': 0.46, 'is_valid': True, 'timestamp': 1628683813, 'counters': [0.431, 0.433, 0.429], 'total': 258969}], 'inputs': [{'input': 0}], 'ext_temperature': {}, 'temperature': 49.61, 'overtemperature': False, 'tmp': {'tC': 49.61, 'tF': 121.3, 'is_valid': 'true'}, 'update': {'status': 'pending', 'has_update': True, 'new_version': '20210727-202339/v1.11.2-g25b6953', 'old_version': '20191219-114622/1047-long-id-for-shelly-devices@d05667c7'}, 'ram_total': 50680, 'ram_free': 39832, 'fs_size': 233681, 'fs_free': 172437, 'uptime': 431844, 'isError': False, 'deviceId': 'P1C2', 'roomId': '2', 'consumption_kwh': 7.666666666666
# ...

# %%
spark = SparkSession.builder.appName('sparkdf').getOrCreate()

# %%
dataframe = spark.createDataFrame(json_test_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-e0eb402f8594> in <module>
# ----> 1 dataframe = spark.createDataFrame(json_test_data)
#
# ~\.conda\envs\tensorflow\lib\site-packages\pyspark\sql\session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     673             return super(SparkSession, self).createDataFrame(
#     674                 data, schema, samplingRatio, verifySchema)
# --> 675         return self._create_dataframe(data, schema, samplingRatio, verifySchema)
#     676
#     677     def _create_dataframe(self, data, schema, samplingRatio, verifySchema):
#
# ~\.conda\envs\tensorflow\lib\site-packages\pyspark\sql\session.py in _create_dataframe(self, data, schema, samplingRatio, verifySchema)
#     698             rdd, schema = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#     699         else:
# ...
