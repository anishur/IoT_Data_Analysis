# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import *
import matplotlib.pylab as plt
import seaborn as sns
plt.close("all")
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
# %matplotlib inline

# %%
df_2 = pd.read_csv('humidity_room3_datetime.csv', parse_dates=["Timestamp"], index_col ="Timestamp", encoding='utf-8')
print(df_2.tail())
# Out:
#                      humidity
# Timestamp
# 2021-06-23 18:50:00        30
# 2021-06-23 19:00:00        31
# 2021-06-23 19:10:00        31
# 2021-06-23 19:20:00        31
# 2021-06-23 19:30:00        31

# %%
## To check the mean value --cell 1

#df_2 = pd.read_csv('humidity_room3_datetime.csv', parse_dates=["Timestamp"], encoding='utf-8')
#print(df_2.tail(60))

# %%
## To check the mean value --cell 2

#total=df_2.loc[2651:2713].sum()
#len(df_2.loc[2651:2713])
#df_2['2021-06-22']
#print(total)

# %%
## To check the mean value --cell 1

#5890/63

# %%
df_max = df_2.groupby(pd.Grouper(freq='d')).max().dropna().rename(columns={"humidity":"humidity_max"}).copy()
print(df_max)
# Out:
#             humidity_max
# Timestamp
# 2021-06-02            86
# 2021-06-03            93
# 2021-06-04            88
# 2021-06-05            72
# 2021-06-06            65
# 2021-06-07            69
# 2021-06-08            72
# 2021-06-09            58
# 2021-06-10            65
# 2021-06-11            69
# 2021-06-12            82
# 2021-06-13            90
# 2021-06-14            88
# 2021-06-15            83
# 2021-06-16            91
# 2021-06-17            96
# 2021-06-18            98
# 2021-06-19            87
# 2021-06-20            97
# 2021-06-21            86
# 2021-06-22            95
# 2021-06-23            38

# %%
idx = pd.date_range('2021-06-02','2021-06-24')
df_max.index = pd.DatetimeIndex(df_max.index)
df_max = df_max.reindex(idx,fill_value=np.nan).copy()
print(df_max)
# Out:
#             humidity_max
# 2021-06-02          86.0
# 2021-06-03          93.0
# 2021-06-04          88.0
# 2021-06-05          72.0
# 2021-06-06          65.0
# 2021-06-07          69.0
# 2021-06-08          72.0
# 2021-06-09          58.0
# 2021-06-10          65.0
# 2021-06-11          69.0
# 2021-06-12          82.0
# 2021-06-13          90.0
# 2021-06-14          88.0
# 2021-06-15          83.0
# 2021-06-16          91.0
# 2021-06-17          96.0
# 2021-06-18          98.0
# 2021-06-19          87.0
# 2021-06-20          97.0
# 2021-06-21          86.0
# 2021-06-22          95.0
# 2021-06-23          38.0
# 2021-06-24           NaN

# %%
df_min = df_2.groupby(pd.Grouper(freq='d')).min().dropna().rename(columns={"humidity":"humidity_min"}).copy()
print(df_min)
# Out:
#             humidity_min
# Timestamp
# 2021-06-02            54
# 2021-06-03            35
# 2021-06-04            24
# 2021-06-05            24
# 2021-06-06            27
# 2021-06-07            28
# 2021-06-08            18
# 2021-06-09            18
# 2021-06-10            23
# 2021-06-11            21
# 2021-06-12            25
# 2021-06-13            35
# 2021-06-14            21
# 2021-06-15            21
# 2021-06-16            43
# 2021-06-17            69
# 2021-06-18            48
# 2021-06-19            63
# 2021-06-20            71
# 2021-06-21            53
# 2021-06-22            71
# 2021-06-23            30

# %%
idx = pd.date_range('2021-06-02','2021-06-24')
df_min.index = pd.DatetimeIndex(df_min.index)
df_min = df_min.reindex(idx,fill_value=np.nan).copy()
print(df_min)
# Out:
#             humidity_min
# 2021-06-02          54.0
# 2021-06-03          35.0
# 2021-06-04          24.0
# 2021-06-05          24.0
# 2021-06-06          27.0
# 2021-06-07          28.0
# 2021-06-08          18.0
# 2021-06-09          18.0
# 2021-06-10          23.0
# 2021-06-11          21.0
# 2021-06-12          25.0
# 2021-06-13          35.0
# 2021-06-14          21.0
# 2021-06-15          21.0
# 2021-06-16          43.0
# 2021-06-17          69.0
# 2021-06-18          48.0
# 2021-06-19          63.0
# 2021-06-20          71.0
# 2021-06-21          53.0
# 2021-06-22          71.0
# 2021-06-23          30.0
# 2021-06-24           NaN

# %%
df_mean = df_2.groupby(pd.Grouper(freq='d')).mean().dropna().rename(columns={"humidity":"humidity_mean"}).copy()
print(df_mean)
# Out:
#             humidity_mean
# Timestamp
# 2021-06-02      71.750000
# 2021-06-03      68.902098
# 2021-06-04      60.160839
# 2021-06-05      47.116788
# 2021-06-06      49.230769
# 2021-06-07      51.790210
# 2021-06-08      49.692308
# 2021-06-09      42.125874
# 2021-06-10      47.398601
# 2021-06-11      52.475524
# 2021-06-12      61.496503
# 2021-06-13      65.225352
# 2021-06-14      57.167832
# 2021-06-15      56.419580
# 2021-06-16      71.685315
# 2021-06-17      85.461538
# 2021-06-18      84.083916
# 2021-06-19      77.776224
# 2021-06-20      91.979167
# 2021-06-21      66.265060
# 2021-06-22      93.492063
# 2021-06-23      33.192308

# %%
idx = pd.date_range('2021-06-02','2021-06-24')
df_mean.index = pd.DatetimeIndex(df_mean.index)
df_mean = df_mean.reindex(idx,fill_value=np.nan).copy()
print(df_mean)

###SAVE File for Tiago ###

#df_mean.to_csv('outside_humidity_june_2021.csv')
# Out:
#             humidity_mean
# 2021-06-02      71.750000
# 2021-06-03      68.902098
# 2021-06-04      60.160839
# 2021-06-05      47.116788
# 2021-06-06      49.230769
# 2021-06-07      51.790210
# 2021-06-08      49.692308
# 2021-06-09      42.125874
# 2021-06-10      47.398601
# 2021-06-11      52.475524
# 2021-06-12      61.496503
# 2021-06-13      65.225352
# 2021-06-14      57.167832
# 2021-06-15      56.419580
# 2021-06-16      71.685315
# 2021-06-17      85.461538
# 2021-06-18      84.083916
# 2021-06-19      77.776224
# 2021-06-20      91.979167
# 2021-06-21      66.265060
# 2021-06-22      93.492063
# 2021-06-23      33.192308
# 2021-06-24            NaN

# %%
frames = [df_max, df_min, df_mean]

result = pd.concat(frames, axis=1, join="inner").copy()

print(result)
# Out:
#             humidity_max  humidity_min  humidity_mean
# 2021-06-02          86.0          54.0      71.750000
# 2021-06-03          93.0          35.0      68.902098
# 2021-06-04          88.0          24.0      60.160839
# 2021-06-05          72.0          24.0      47.116788
# 2021-06-06          65.0          27.0      49.230769
# 2021-06-07          69.0          28.0      51.790210
# 2021-06-08          72.0          18.0      49.692308
# 2021-06-09          58.0          18.0      42.125874
# 2021-06-10          65.0          23.0      47.398601
# 2021-06-11          69.0          21.0      52.475524
# 2021-06-12          82.0          25.0      61.496503
# 2021-06-13          90.0          35.0      65.225352
# 2021-06-14          88.0          21.0      57.167832
# 2021-06-15          83.0          21.0      56.419580
# 2021-06-16          91.0          43.0      71.685315
# 2021-06-17          96.0          69.0      85.461538
# ...

# %%
df = pd.DataFrame(result, columns=['humidity_max','humidity_min','humidity_mean'])

boxplot = df.boxplot(column=['humidity_max','humidity_min','humidity_mean'],patch_artist=True)

# %%
result.plot()
plt.grid(color='green',linestyle='--', linewidth=0.5)
#plt.mgrid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,5))
#fig, ax = plt.subplots(1)


ax.set_ylim(0,100)


ax.set_ylabel('Daily Humidity %')
ax.set_xlabel('June 2021')
ax.set_title('June 2021 Room3 Humidity in %')

#ax.plot(result.loc['2021-06-02':'2021-06-24', ['humidity_max','humidity_min','humidity_mean']],marker='o', linestyle='-')
ax.plot(result.loc['2021-06-02':'2021-06-24', ['humidity_max','humidity_mean','humidity_min']],marker='o', linestyle='-')

ax.xaxis.set_major_locator(mdates.DayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d'))


#plt.legend(["humidity_max","humidity_min","humidity_mean"],loc='best')
plt.legend(["Max humidity","Mean humidity","Min humidity"],loc='best')

plt.grid(color='green',linestyle='--', linewidth=0.5)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,5))
#fig, ax = plt.subplots(1)


#ax.set_ylim(10,100)


ax.set_ylabel('Daily Humidity ºC')
ax.set_xlabel('June 2021')
ax.set_title('June 2021 Room2 Humidity in ºC')

#ax.plot(result.loc['2021-06-02':'2021-06-24', ['humidity_max','humidity_min','humidity_mean']],marker='o', linestyle='-')
ax.plot(result.loc['2021-06-02':'2021-06-24', ['humidity_max','humidity_mean','humidity_min']],marker='o', linestyle='-')

ax.xaxis.set_major_locator(mdates.DayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d'))


#plt.legend(["humidity_max","humidity_min","humidity_mean"],loc='best')
plt.legend(["Max humidity","Mean humidity","Min humidity"],loc='best')

plt.grid(color='green',linestyle='--', linewidth=0.5)
plt.show()
