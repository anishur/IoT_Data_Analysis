# %%
#!pip install petl
#!pip install cdata
#!pip install missingno
#!pip install plotly

# %%
#import petl as etl
import pandas as pd
#import cdata.mongodb as mod
from pymongo import MongoClient
import missingno
import seaborn as sns

# %%
#client= MongoClient("mongodb+srv://cecoDbUser:cecoUser2021@dashboard.agmyi.mongodb.net/DashBoard?retryWrites=true&w=majority")

client.close()

# %%
db = client.get_database('DashBoard')

# %%
records = db.ArduinoNanoBLE_Test

# %%
records.count_documents({})
# Out:
# 1171

# %%
list(records.find())
# Out:
# [{'_id': ObjectId('61154580c76b40756ef8ec56'),
#   'temperature_celcius': 29.93,
#   'humidity_percentage': 56.89,
#   'pressure_kpa': 97.55,
#   'roomId': '1',
#   'date': datetime.datetime(2021, 8, 12, 15, 59, 57, 986000)},
#  {'_id': ObjectId('6116466084b4aa61d40e64f3'),
#   'temperature_celcius': 28.47,
#   'humidity_percentage': 58.11,
#   'pressure_kpa': 97.71,
#   'roomId': '1',
#   'date': datetime.datetime(2021, 8, 13, 10, 15, 56, 258000)},
#  {'_id': ObjectId('6116474a2c9c0f79efca8c4f'),
#   'temperature_celcius': 28.92,
#   'humidity_percentage': 57.49,
#   'pressure_kpa': 97.71,
#   'roomId': '1',
#   'date': datetime.datetime(2021, 8, 13, 10, 19, 52, 38000)},
#  {'_id': ObjectId('611648b8619fe92c8a3f799d'),
#   'temperature_celcius': 29.04,
#   'humidity_percentage': 57.01,
#   'pressure_kpa': 97.72,
#   'roomId': '1',
#   'date': datetime.datetime(2021, 8, 13, 10, 25, 57, 569000)},
#  {'_id': ObjectId('6116493feb51675398f7ee7d'),
#   'temperature_celcius': 29.0,
# ...

# %%
list1=list(records.find({'roomId':'1'}))

# %%
print(list1)
type(list1)
# Out:
# [{'_id': ObjectId('61154580c76b40756ef8ec56'), 'temperature_celcius': 29.93, 'humidity_percentage': 56.89, 'pressure_kpa': 97.55, 'roomId': '1', 'date': datetime.datetime(2021, 8, 12, 15, 59, 57, 986000)}, {'_id': ObjectId('6116466084b4aa61d40e64f3'), 'temperature_celcius': 28.47, 'humidity_percentage': 58.11, 'pressure_kpa': 97.71, 'roomId': '1', 'date': datetime.datetime(2021, 8, 13, 10, 15, 56, 258000)}, {'_id': ObjectId('6116474a2c9c0f79efca8c4f'), 'temperature_celcius': 28.92, 'humidity_percentage': 57.49, 'pressure_kpa': 97.71, 'roomId': '1', 'date': datetime.datetime(2021, 8, 13, 10, 19, 52, 38000)}, {'_id': ObjectId('611648b8619fe92c8a3f799d'), 'temperature_celcius': 29.04, 'humidity_percentage': 57.01, 'pressure_kpa': 97.72, 'roomId': '1', 'date': datetime.datetime(2021, 8, 13, 10, 25, 57, 569000)}, {'_id': ObjectId('6116493feb51675398f7ee7d'), 'temperature_celcius': 29.0, 'humidity_percentage': 56.9, 'pressure_kpa': 97.71, 'roomId': '1', 'date': datetime.datetime(2021, 8, 1
# ...

# %%
list1[-1]["date"]
# Out:
# datetime.datetime(2021, 8, 17, 15, 13, 7, 188000)

# %%
df = pd.DataFrame(list1)

# %%
df
# Out:
#                           _id  temperature_celcius  humidity_percentage  \
# 0    61154580c76b40756ef8ec56                29.93                56.89
# 1    6116466084b4aa61d40e64f3                28.47                58.11
# 2    6116474a2c9c0f79efca8c4f                28.92                57.49
# 3    611648b8619fe92c8a3f799d                29.04                57.01
# 4    6116493feb51675398f7ee7d                29.00                56.90
# ..                        ...                  ...                  ...
# 588  611bc8a4011a2b308fc58122                29.48                45.00
# 589  611bcafc011a2b308fc581f0                29.57                45.29
# 590  611bcd54011a2b308fc582be                29.67                45.02
# 591  611bcfac011a2b308fc58388                29.65                45.49
# 592  611bd204011a2b308fc58432                29.59                45.35
#
#      pressure_kpa roomId                    date
# 0           97.55      1 2021-08-12 15:59:57.986
# ...

# %%
cols = ['date','roomId','humidity_percentage','pressure_kpa']

# %%
df = df[cols].copy()

# %%
df
# Out:
#                        date roomId  humidity_percentage  pressure_kpa
# 0   2021-08-12 15:59:57.986      1                56.89         97.55
# 1   2021-08-13 10:15:56.258      1                58.11         97.71
# 2   2021-08-13 10:19:52.038      1                57.49         97.71
# 3   2021-08-13 10:25:57.569      1                57.01         97.72
# 4   2021-08-13 10:28:12.552      1                56.90         97.71
# ..                      ...    ...                  ...           ...
# 588 2021-08-17 14:33:07.188      1                45.00         97.59
# 589 2021-08-17 14:43:07.188      1                45.29         97.58
# 590 2021-08-17 14:53:07.187      1                45.02         97.57
# 591 2021-08-17 15:03:07.188      1                45.49         97.57
# 592 2021-08-17 15:13:07.188      1                45.35         97.56
#
# [593 rows x 4 columns]

# %%
import plotly.express as px

plot = px.data.gapminder().query("df=='humidity_percentage'")
fig = px.line(plot, x='date', y='humidity_percentage')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\tensorflow\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     187             if self.has_resolvers:
# --> 188                 return self.resolvers[key]
#     189
#
# ~\.conda\envs\tensorflow\lib\collections\__init__.py in __getitem__(self, key)
#     882                 pass
# --> 883         return self.__missing__(key)            # support subclasses that define __missing__
#     884
#
# ~\.conda\envs\tensorflow\lib\collections\__init__.py in __missing__(self, key)
#     874     def __missing__(self, key):
# --> 875         raise KeyError(key)
#     876
#
# KeyError: 'df'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [raw]
# fig, ax = plt.subplots(figsize=(10,5))
#
# plot = sns.lineplot(ax = ax, data = df, x="date", y=["humidity_percentage","pressure_kpa"])
#
# ax.set_xticklabels([])
#
# plt.show()

# %%
#missingno.bar(london_housing, figsize=(10,5), fontsize=12);
missingno.bar(df, figsize=(10,5), fontsize=12)
# Out:
# <AxesSubplot:>

# %%
missingno.heatmap(df)
# Out:
# C:\Users\Lenovo\.conda\envs\tensorflow\lib\site-packages\seaborn\matrix.py:311: UserWarning:
#
# Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#
# C:\Users\Lenovo\.conda\envs\tensorflow\lib\site-packages\seaborn\matrix.py:311: UserWarning:
#
# Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
# <AxesSubplot:>

# %%
df.plot(x="date", y=["humidity_percentage","pressure_kpa"], figsize=(16,5), grid=True)
plt.ylim(0,100)
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# %%
df
# Out:
#                         roomId  humidity_percentage  pressure_kpa
# date
# 2021-08-12 15:59:57.986      1                56.89         97.55
# 2021-08-13 10:15:56.258      1                58.11         97.71
# 2021-08-13 10:19:52.038      1                57.49         97.71
# 2021-08-13 10:25:57.569      1                57.01         97.72
# 2021-08-13 10:28:12.552      1                56.90         97.71
# ...                        ...                  ...           ...
# 2021-08-17 14:33:07.188      1                45.00         97.59
# 2021-08-17 14:43:07.188      1                45.29         97.58
# 2021-08-17 14:53:07.187      1                45.02         97.57
# 2021-08-17 15:03:07.188      1                45.49         97.57
# 2021-08-17 15:13:07.188      1                45.35         97.56
#
# [593 rows x 3 columns]

# %% [raw]
# import plotly.express as px
#
# #df = px.data.gapminder().query("country in ['Canada', 'Botswana']")
# df = px.data.gapminder().query("continent=='Oceania'")
# fig = px.line(df, x="year", y="lifeExp", color='country')
# fig.show()

# %%
fig, ax = plt.subplots(figsize=(16,5))

#plot = sns.lineplot(ax = ax, data = df, x="date", y=["humidity_percentage","pressure_kpa"])
plot = sns.lineplot(ax = ax, data = df, x="date", y="humidity_percentage")
plot = sns.lineplot(ax = ax, data = df, x="date", y="pressure_kpa")

ax.set_xticklabels([])
plt.grid()
plt.show()

# %%
df = df.rename(columns={'humidity_percentage':'humidity','pressure_kpa':'pressure'})

# %%
df
# Out:
#                         roomId  humidity  pressure
# date
# 2021-08-12 15:59:57.986      1     56.89     97.55
# 2021-08-13 10:15:56.258      1     58.11     97.71
# 2021-08-13 10:19:52.038      1     57.49     97.71
# 2021-08-13 10:25:57.569      1     57.01     97.72
# 2021-08-13 10:28:12.552      1     56.90     97.71
# ...                        ...       ...       ...
# 2021-08-17 09:41:14.088      1     50.30     97.81
# 2021-08-17 09:51:14.088      1     49.10     97.81
# 2021-08-17 10:01:14.089      1     48.96     97.81
# 2021-08-17 10:11:14.088      1     48.90     97.81
# 2021-08-17 10:21:14.088      1     48.77     97.80
#
# [578 rows x 3 columns]

# %%
cols2 = ['humidity','pressure']

# %%
df = df[cols2]

# %%
df
# Out:
#                          humidity  pressure
# date
# 2021-08-12 15:59:57.986     56.89     97.55
# 2021-08-13 10:15:56.258     58.11     97.71
# 2021-08-13 10:19:52.038     57.49     97.71
# 2021-08-13 10:25:57.569     57.01     97.72
# 2021-08-13 10:28:12.552     56.90     97.71
# ...                           ...       ...
# 2021-08-17 09:41:14.088     50.30     97.81
# 2021-08-17 09:51:14.088     49.10     97.81
# 2021-08-17 10:01:14.089     48.96     97.81
# 2021-08-17 10:11:14.088     48.90     97.81
# 2021-08-17 10:21:14.088     48.77     97.80
#
# [578 rows x 2 columns]
